# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('img1.jpeg',0)
img2 = cv2.imread('img2.jpeg',0)

# %%
# Initiate SIFT detector
orb = cv2.ORB_create()

# %%
# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# %%
# Match descriptors.
matches = bf.match(des1,des2)

# %%
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# %%
# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x18c82d450>, None)

# %%
# 호모그래피 계산
# DMatch 객체에서 queryIdx와 trainIdx를 받아와서 크기와 타입 변환하기
pts1 = np.array([kp1[m.queryIdx].pt for m in img3]
				).reshape(-1, 1, 2).astype(np.float32)
pts2 = np.array([kp1[m.trainIdx].pt for m in img3]
				).reshape(-1, 1, 2).astype(np.float32)
                
H, _ = cv2.findHomography(pts1, pts2, cv2.RANSAC) # pts1과 pts2의 행렬 주의 (N,1,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 3>()
#       1 # 호모그래피 계산
#       2 # DMatch 객체에서 queryIdx와 trainIdx를 받아와서 크기와 타입 변환하기
# ----> 3 pts1 = np.array([kp1[m.queryIdx].pt for m in good_matches]
#       4 				).reshape(-1, 1, 2).astype(np.float32)
#       5 pts2 = np.array([kp1[m.trainIdx].pt for m in good_matches]
#       6 				).reshape(-1, 1, 2).astype(np.float32)
#       8 H, _ = cv2.findHomography(pts1, pts2, cv2.RANSAC)
#
# NameError: name 'good_matches' is not defined

# %%
# Out:
# Package               Version
# --------------------- --------
# cycler                0.11.0
# fonttools             4.36.0
# kiwisolver            1.4.4
# matplotlib            3.5.3
# numpy                 1.23.2
# opencv-python         4.6.0.66
# packaging             21.3
# Pillow                9.2.0
# pip                   22.2.2
# protobuf              4.21.5
# pyparsing             3.0.9
# PyQt3D                5.15.5
# PyQt5                 5.15.7
# PyQt5-sip             12.11.0
# PyQtChart             5.15.6
# PyQtDataVisualization 5.15.5
# PyQtNetworkAuth       5.15.5
# PyQtPurchasing        5.15.5
# PyQtWebEngine         5.15.6
# python-dateutil       2.8.2
# setuptools            63.4.3
# six                   1.16.0
# TBB                   0.2
# wheel                 0.37.1
