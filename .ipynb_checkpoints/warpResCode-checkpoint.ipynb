# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('img1.jpeg',0)
img2 = cv2.imread('img2.jpeg',0)

# %%
# Initiate SIFT detector
orb = cv2.ORB_create()

# %%
# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# %%
# Match descriptors.
matches = bf.match(des1,des2)

# %%
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# %%
# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=2)
plt.imshow(img3),plt.show()

# %%
# Out:
# (<matplotlib.image.AxesImage at 0x18c7b19f0>, None)

# %%
# Out:
# [< cv2.DMatch 0x18d4f90d0>, < cv2.DMatch 0x18d4f8c90>, < cv2.DMatch 0x18d4f9530>, < cv2.DMatch 0x18d4f9250>, < cv2.DMatch 0x18d4f8c30>, < cv2.DMatch 0x18d4f8a50>, < cv2.DMatch 0x18d4f8910>, < cv2.DMatch 0x18d4f8ff0>, < cv2.DMatch 0x18d4f8f10>, < cv2.DMatch 0x18d4f8d70>]
